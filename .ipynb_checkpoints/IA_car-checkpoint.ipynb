# %% [markdown]
# # P1

# %%
import numpy as np
import keras
import time
import os
import cv2
from keras import backend as k
from keras.models import Sequential
from keras.layers import Activation
#from keras.layers import Dense, Flatten, Dropout #type de couches
from keras.layers import Dense, Flatten, Dropout #type de couches
from keras.layers import Conv2D, MaxPooling2D
#from keras.layers import BatchNormalization
from keras.layers import BatchNormalization
#from tensorflow.keras.optimizers import Adam
from keras.optimizers import Adam
from keras.metrics import binary_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot as plt
# Out:
# Jupyter ne peut pas être démarré. Erreur lors de la tentative de localisation de Jupyter : Les cellules en cours d’exécution avec Python 3.13.0 nécessitent le package notebook et jupyter.
#
# Exécutez la commande suivante pour installer 'jupyter et notebook' dans l’environnement Python.
#
# Commande : 'python -m pip install jupyter notebook -U
#
# or
#
# conda install jupyter notebook -U'
#
# Cliquez sur <a href='https://aka.ms/installJupyterForVSCode'>ici</a> pour plus d’informations.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # P2

# %%
train_path = '/content/drive/MyDrive/IA_ML/data/train/'
valid_path = '/content/drive/MyDrive/IA_ML/data/valid/'

batch_size = 32

train_batches = ImageDataGenerator().flow_from_directory(
    train_path,
    target_size=(100, 100),
    batch_size=batch_size,
    class_mode='binary'  # Utilisez 'binary' pour distinguer voitures et non-voitures
)

valid_batches = ImageDataGenerator().flow_from_directory(
    valid_path,
    target_size=(100, 100),
    batch_size=batch_size,
    class_mode='binary'  # Même mode que pour l'entraînement

)

print(train_batches.class_indices)  # Devrait afficher {'car': 0, 'not_car': 1} ou l'inverse
# Out:
# Found 904 images belonging to 2 classes.
# Found 903 images belonging to 2 classes.
# {'car': 0, 'not_car': 1}

# %%
#steps_train = train_batches.n / batch_size
steps_train = len(train_batches)
steps_train
# Out:
# 29

# %%
#steps_valid = valid_batches.n / batch_size
steps_valid = len(valid_batches)
steps_valid
# Out:
# 29

# %%
num_classes = train_batches.num_classes
num_classes
# Out:
# 2

# %%
cls_train = train_batches.classes
cls_test =  valid_batches.classes
class_names = list(train_batches.class_indices.keys())
class_names
# Out:
# ['car', 'not_car']

# %%
def path_join(dirname, filenames):
    return [os.path.join(dirname, filename) for filename in filenames]
image_paths_train = path_join(train_path, train_batches.filenames)
image_paths_test = path_join(valid_path, valid_batches.filenames)

def plot_images(images, cls_true, cls_pred=None, smooth=True):
    assert len(images) == len(cls_true)

    # Create figure with sub-plots.
    fig, axes = plt.subplots(3, 3)

    # Adjust vertical spacing.
    if cls_pred is None:
        hspace = 0.3
    else:
        hspace = 0.6
    fig.subplots_adjust(hspace=hspace, wspace=0.3)

    # Interpolation type.
    if smooth:
        interpolation = 'spline16'
    else:
        interpolation = 'nearest'

    for i, ax in enumerate(axes.flat):
        # There may be less than 9 images, ensure it doesn't crash.
        if i < len(images):
            # Plot image.
            ax.imshow(images[i],
                      interpolation=interpolation)

            # Name of the true class.
            cls_true_name = class_names[cls_true[i]]

            # Show true and predicted classes.
            if cls_pred is None:
                xlabel = "True: {0}".format(cls_true_name)
            else:
                # Name of the predicted class.
                cls_pred_name = class_names[cls_pred[i]]
                xlabel = "True: {0}\nPred: {1}".format(cls_true_name, cls_pred_name)
            # Show the classes as the label on the x-axis.
            ax.set_xlabel(xlabel)
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])

    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()

def load_images(image_paths):
    # Load the images from disk.
    images = [plt.imread(path) for path in image_paths]
    # Convert to a numpy array and return it.
    return np.asarray(images)

# %%
# Load the first images from the train-set.
images = load_images(image_paths=image_paths_train[0:9])
# Get the true classes for those images.
cls_true = cls_train[0:9]
# Plot the images and labels using our helper-function above.
plot_images(images=images, cls_true=cls_true, smooth=True)

# %% [markdown]
# # P3

# %%
from keras.layers import Input

model = Sequential([
    Input(shape=(100, 100, 3)),  # Définir l'entrée explicitement
    Conv2D(32, kernel_size=(3, 3), activation='relu'),
    Conv2D(32, kernel_size=(3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2), strides=(2, 2)),

    Conv2D(64, kernel_size=(3, 3), activation='relu'),
    Conv2D(64, kernel_size=(3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2), strides=(2, 2)),

    Flatten(),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_47 (Conv2D)                   │ (None, 98, 98, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_48 (Conv2D)                   │ (None, 96, 96, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_25               │ (None, 96, 96, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %% [markdown]
# # P4

# %%
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
start = time.time()

history = model.fit(
    train_batches,
    epochs=epochs,
    steps_per_epoch=int(steps_train),  # Conversion en entier
    validation_data=valid_batches,
    validation_steps=int(steps_valid)  # Conversion en entier
)
# Out:
# Epoch 1/10
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 84s 3s/step - accuracy: 0.7766 - loss: 0.5860 - val_accuracy: 0.7674 - val_loss: 0.5683
# Epoch 2/10
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/10
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.7582 - loss: 0.5569 - val_accuracy: 0.7674 - val_loss: 0.5775
# Epoch 4/10
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/10
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - accuracy: 0.7615 - loss: 0.5449 - val_accuracy: 0.7674 - val_loss: 0.5736
# Epoch 6/10
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/10
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - accuracy: 0.7761 - loss: 0.5384 - val_accuracy: 0.7674 - val_loss: 0.5616
# Epoch 8/10
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/10
# ...

# %%
end = time.time()

# %%
print ("Model took %0.2f seconds to train"%(end - start))
result = model.evaluate(valid_batches, steps=1)
print("Test-set classification accuracy: {0:.2%}".format(result[1]))
# Out:
# Model took 410.42 seconds to train
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 693ms/step - accuracy: 0.7812 - loss: 0.5526
# Test-set classification accuracy: 78.12%

# %% [markdown]
# # P5

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['accuracy'])+1),model_history.history['accuracy'])
    axs[0].plot(range(1,len(model_history.history['val_accuracy'])+1),model_history.history['val_accuracy'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    #axs[0].set_xticks(np.arange(1,len(model_history.history['accuracy'])+1),len(model_history.history['accuracy'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    #axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

plot_model_history(history)

# %% [markdown]
# # P6

# %%
img = cv2.imread('/content/drive/MyDrive/IA_ML/data/valid/not_car/0100.png')
# show the image
plt.imshow(img, interpolation = 'spline16')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()
img = cv2.resize(img,(100,100))
img = np.reshape(img,[1,100,100,3])
img = img / 255.0  # Normalisation de l'image entre 0 et 1 avant prédiction


predic = model.predict(img)
if predic[0][0] > 0.5:
    print("C'est une voiture avec {:.2f}% de confiance".format(predic[0][0] * 100))
else:
    print("Ce n'est pas une voiture avec {:.2f}% de confiance".format((1 - predic[0][0]) * 100))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# C'est une voiture avec 67.56% de confiance
