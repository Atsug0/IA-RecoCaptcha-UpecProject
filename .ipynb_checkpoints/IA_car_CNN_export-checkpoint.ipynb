# %%
import numpy as np
import keras
import time
import os
import cv2
import math
from keras import backend as k
from keras.models import Sequential
from keras.layers import Activation
#from keras.layers import Dense, Flatten, Dropout #type de couches
from keras.layers import Dense, Flatten, Dropout #type de couches
from keras.layers import Conv2D, MaxPooling2D
#from keras.layers import BatchNormalization
from keras.layers import BatchNormalization
#from tensorflow.keras.optimizers import Adam
from keras.optimizers import Adam
from keras.metrics import binary_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_path = 'data/train/'
valid_path = 'data/valid/'

batch_size = 32

# Création des générateurs avec augmentation de données pour l'entraînement

train_datagen = ImageDataGenerator(
    rescale=1.0 / 255,        # Normalisation
    rotation_range=20,        # Rotation aléatoire
    width_shift_range=0.2,    # Décalage horizontal
    height_shift_range=0.2,   # Décalage vertical
    shear_range=0.2,          # Transformation en cisaillement
    zoom_range=0.2,           # Zoom aléatoire
    horizontal_flip=True      # Inversion horizontale
)


# Générateur de validation avec uniquement une normalisation
valid_datagen = ImageDataGenerator(
    rescale=1.0/255.0  # Normalisation sans augmentation de données
)

# Chargement des images augmentées pour l'entraînement
train_batches = train_datagen.flow_from_directory(
    train_path,
    target_size=(100, 100),
    batch_size=batch_size,
    class_mode='binary'  # Binaire : car / not_car
)

# Chargement des images de validation
valid_batches = valid_datagen.flow_from_directory(
    valid_path,
    target_size=(100, 100),
    batch_size=batch_size,
    class_mode='binary'
)

steps_train = train_batches.samples // train_batches.batch_size

steps_valid = valid_batches.samples // valid_batches.batch_size
num_classes = train_batches.num_classes

cls_train = train_batches.classes
cls_test =  valid_batches.classes
class_names = list(train_batches.class_indices.keys())
# Out:
# Found 418 images belonging to 2 classes.
# Found 418 images belonging to 2 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Définition d'un modèle CNN simple
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(100, 100, 3)),
    MaxPooling2D(2, 2),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')  # Sortie binaire
])

# Compilation du modèle
model.compile(optimizer=Adam(learning_rate=1e-4), loss='binary_crossentropy', metrics=['accuracy'])

# Résumé du modèle
model.summary()
# Out:
# /Users/atsug0/Desktop/master/ia/IA-RecoCaptcha-UpecProject/myenv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 98, 98, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 49, 49, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 47, 47, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 33856)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │     4,333,696 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,353,217 (16.61 MB)
#  Trainable params: 4,353,217 (16.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau


# Callbacks

start = time.time()

import matplotlib.pyplot as plt

history = model.fit(train_batches, validation_data=valid_batches, epochs=100, verbose=1)

end = time.time()

print(f"Le modèle a été entraîné en {end - start:.2f} secondes.")
# Out:
# Epoch 1/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 248ms/step - accuracy: 0.5319 - loss: 0.7047 - val_accuracy: 0.5000 - val_loss: 0.6914
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - accuracy: 0.5506 - loss: 0.6944 - val_accuracy: 0.5766 - val_loss: 0.6459
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 0.5932 - loss: 0.6739 - val_accuracy: 0.6172 - val_loss: 0.6232
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 0.6601 - loss: 0.6381 - val_accuracy: 0.7799 - val_loss: 0.5527
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - accuracy: 0.7307 - loss: 0.5706 - val_accuracy: 0.7440 - val_loss: 0.5365
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - accuracy: 0.7336 - loss: 0.5521 - val_accuracy: 0.8421 - val_loss: 0.4665
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - accuracy: 0.6823 - loss: 0.5675 - val_accuracy: 0.7943 - val_loss: 0.4720
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 227ms/step - accuracy: 0.7211 - loss: 0.5825 - val_accuracy: 0.8230 - val_loss: 0.4540
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - accuracy: 0.7865 - loss: 0.5034 - val_accuracy: 0.8445 - val_loss: 0.4218
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 253ms/step - accuracy: 0.7724 - loss: 0.4967 - val_accuracy: 0.7823 - val_loss: 0.4736
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 278ms/step - accuracy: 0.7532 - loss: 0.5171 - val_accuracy: 0.8517 - val_loss: 0.3972
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - accuracy: 0.8027 - loss: 0.4801 - val_accuracy: 0.8636 - val_loss: 0.3761
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step - accuracy: 0.8350 - loss: 0.4292 - val_accuracy: 0.8732 - val_loss: 0.3453
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - accuracy: 0.8196 - loss: 0.4157 - val_accuracy: 0.8349 - val_loss: 0.3735
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 220ms/step - accuracy: 0.7929 - loss: 0.4533 - val_accuracy: 0.8493 - val_loss: 0.3654
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 233ms/step - accuracy: 0.8004 - loss: 0.4597 - val_accuracy: 0.8804 - val_loss: 0.3479
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step - accuracy: 0.8124 - loss: 0.4579 - val_accuracy: 0.8756 - val_loss: 0.3311
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 235ms/step - accuracy: 0.8271 - loss: 0.4291 - val_accuracy: 0.8636 - val_loss: 0.3363
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 260ms/step - accuracy: 0.8183 - loss: 0.4305 - val_accuracy: 0.8756 - val_loss: 0.3211
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 345ms/step - accuracy: 0.8269 - loss: 0.4239 - val_accuracy: 0.8876 - val_loss: 0.3199
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 241ms/step - accuracy: 0.8124 - loss: 0.4380 - val_accuracy: 0.8589 - val_loss: 0.3437
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 261ms/step - accuracy: 0.8161 - loss: 0.4272 - val_accuracy: 0.8780 - val_loss: 0.3211
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 247ms/step - accuracy: 0.8200 - loss: 0.4323 - val_accuracy: 0.8900 - val_loss: 0.3006
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - accuracy: 0.7824 - loss: 0.4860 - val_accuracy: 0.8804 - val_loss: 0.3029
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 229ms/step - accuracy: 0.8413 - loss: 0.4006 - val_accuracy: 0.8947 - val_loss: 0.2931
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 207ms/step - accuracy: 0.8258 - loss: 0.4063 - val_accuracy: 0.8900 - val_loss: 0.2905
# Epoch 27/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - accuracy: 0.8229 - loss: 0.4128 - val_accuracy: 0.8828 - val_loss: 0.2866
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - accuracy: 0.8140 - loss: 0.4126 - val_accuracy: 0.8828 - val_loss: 0.2817
# Epoch 29/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - accuracy: 0.8199 - loss: 0.4256 - val_accuracy: 0.8876 - val_loss: 0.2803
# Epoch 30/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 0.8285 - loss: 0.4103 - val_accuracy: 0.8947 - val_loss: 0.2759
# Epoch 31/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - accuracy: 0.8389 - loss: 0.3951 - val_accuracy: 0.8876 - val_loss: 0.2809
# Epoch 32/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - accuracy: 0.8556 - loss: 0.3802 - val_accuracy: 0.8947 - val_loss: 0.2696
# Epoch 33/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 0.8203 - loss: 0.3931 - val_accuracy: 0.8971 - val_loss: 0.2733
# Epoch 34/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 284ms/step - accuracy: 0.8248 - loss: 0.4350 - val_accuracy: 0.8876 - val_loss: 0.2909
# Epoch 35/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 271ms/step - accuracy: 0.8233 - loss: 0.3856 - val_accuracy: 0.9067 - val_loss: 0.2832
# Epoch 36/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 274ms/step - accuracy: 0.8319 - loss: 0.4020 - val_accuracy: 0.8852 - val_loss: 0.2854
# Epoch 37/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 256ms/step - accuracy: 0.8488 - loss: 0.3673 - val_accuracy: 0.8852 - val_loss: 0.2716
# Epoch 38/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 255ms/step - accuracy: 0.8241 - loss: 0.4058 - val_accuracy: 0.9067 - val_loss: 0.2661
# Epoch 39/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 279ms/step - accuracy: 0.8556 - loss: 0.3868 - val_accuracy: 0.8876 - val_loss: 0.2696
# Epoch 40/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 286ms/step - accuracy: 0.8056 - loss: 0.3914 - val_accuracy: 0.8947 - val_loss: 0.2682
# Epoch 41/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 277ms/step - accuracy: 0.8539 - loss: 0.3795 - val_accuracy: 0.8804 - val_loss: 0.2997
# Epoch 42/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 261ms/step - accuracy: 0.8015 - loss: 0.4160 - val_accuracy: 0.9067 - val_loss: 0.2850
# Epoch 43/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 284ms/step - accuracy: 0.8135 - loss: 0.4461 - val_accuracy: 0.8876 - val_loss: 0.2730
# Epoch 44/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 267ms/step - accuracy: 0.8142 - loss: 0.4022 - val_accuracy: 0.9091 - val_loss: 0.2559
# Epoch 45/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 262ms/step - accuracy: 0.8094 - loss: 0.4160 - val_accuracy: 0.8876 - val_loss: 0.2823
# Epoch 46/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 263ms/step - accuracy: 0.8196 - loss: 0.4092 - val_accuracy: 0.8876 - val_loss: 0.2658
# Epoch 47/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - accuracy: 0.8273 - loss: 0.3917 - val_accuracy: 0.9139 - val_loss: 0.2691
# Epoch 48/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - accuracy: 0.8171 - loss: 0.4071 - val_accuracy: 0.9091 - val_loss: 0.2770
# Epoch 49/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - accuracy: 0.8405 - loss: 0.3774 - val_accuracy: 0.9067 - val_loss: 0.2580
# Epoch 50/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - accuracy: 0.8787 - loss: 0.3375 - val_accuracy: 0.9067 - val_loss: 0.2509
# Epoch 51/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 205ms/step - accuracy: 0.8617 - loss: 0.3490 - val_accuracy: 0.9163 - val_loss: 0.2437
# Epoch 52/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 174ms/step - accuracy: 0.8605 - loss: 0.3264 - val_accuracy: 0.9211 - val_loss: 0.2527
# Epoch 53/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 177ms/step - accuracy: 0.7892 - loss: 0.4944 - val_accuracy: 0.9234 - val_loss: 0.2384
# Epoch 54/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - accuracy: 0.8362 - loss: 0.3831 - val_accuracy: 0.8493 - val_loss: 0.3328
# Epoch 55/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - accuracy: 0.8091 - loss: 0.3961 - val_accuracy: 0.9187 - val_loss: 0.2470
# Epoch 56/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 0.8287 - loss: 0.3828 - val_accuracy: 0.8493 - val_loss: 0.3480
# Epoch 57/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - accuracy: 0.8290 - loss: 0.4256 - val_accuracy: 0.9187 - val_loss: 0.2570
# Epoch 58/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - accuracy: 0.8644 - loss: 0.3478 - val_accuracy: 0.8804 - val_loss: 0.2931
# Epoch 59/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - accuracy: 0.8478 - loss: 0.3692 - val_accuracy: 0.8780 - val_loss: 0.3033
# Epoch 60/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 0.8472 - loss: 0.3614 - val_accuracy: 0.8995 - val_loss: 0.2747
# Epoch 61/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - accuracy: 0.8563 - loss: 0.3695 - val_accuracy: 0.9115 - val_loss: 0.2679
# Epoch 62/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 186ms/step - accuracy: 0.8424 - loss: 0.3945 - val_accuracy: 0.9091 - val_loss: 0.2463
# Epoch 63/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step - accuracy: 0.8310 - loss: 0.3923 - val_accuracy: 0.9139 - val_loss: 0.2508
# Epoch 64/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - accuracy: 0.8345 - loss: 0.3546 - val_accuracy: 0.9187 - val_loss: 0.2435
# Epoch 65/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 0.8707 - loss: 0.3557 - val_accuracy: 0.9115 - val_loss: 0.2539
# Epoch 66/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 205ms/step - accuracy: 0.8617 - loss: 0.3705 - val_accuracy: 0.9115 - val_loss: 0.2495
# Epoch 67/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - accuracy: 0.8686 - loss: 0.3222 - val_accuracy: 0.9163 - val_loss: 0.2450
# Epoch 68/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - accuracy: 0.8874 - loss: 0.3486 - val_accuracy: 0.9187 - val_loss: 0.2429
# Epoch 69/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - accuracy: 0.8568 - loss: 0.3387 - val_accuracy: 0.9139 - val_loss: 0.2477
# Epoch 70/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - accuracy: 0.8210 - loss: 0.3605 - val_accuracy: 0.9139 - val_loss: 0.2551
# Epoch 71/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - accuracy: 0.8529 - loss: 0.3533 - val_accuracy: 0.8900 - val_loss: 0.2849
# Epoch 72/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - accuracy: 0.8572 - loss: 0.3479 - val_accuracy: 0.8900 - val_loss: 0.2853
# Epoch 73/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - accuracy: 0.8567 - loss: 0.3609 - val_accuracy: 0.9091 - val_loss: 0.2382
# Epoch 74/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - accuracy: 0.8621 - loss: 0.3237 - val_accuracy: 0.8828 - val_loss: 0.2811
# Epoch 75/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - accuracy: 0.8651 - loss: 0.3191 - val_accuracy: 0.9163 - val_loss: 0.2411
# Epoch 76/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - accuracy: 0.8629 - loss: 0.3269 - val_accuracy: 0.9211 - val_loss: 0.2281
# Epoch 77/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - accuracy: 0.8379 - loss: 0.3832 - val_accuracy: 0.9091 - val_loss: 0.2573
# Epoch 78/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 0.8594 - loss: 0.3468 - val_accuracy: 0.9139 - val_loss: 0.2405
# Epoch 79/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - accuracy: 0.8488 - loss: 0.3316 - val_accuracy: 0.9139 - val_loss: 0.2344
# Epoch 80/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - accuracy: 0.8987 - loss: 0.2784 - val_accuracy: 0.9139 - val_loss: 0.2311
# Epoch 81/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - accuracy: 0.8525 - loss: 0.3310 - val_accuracy: 0.9163 - val_loss: 0.2324
# Epoch 82/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - accuracy: 0.9073 - loss: 0.2667 - val_accuracy: 0.9163 - val_loss: 0.2202
# Epoch 83/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - accuracy: 0.8585 - loss: 0.3385 - val_accuracy: 0.9139 - val_loss: 0.2345
# Epoch 84/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - accuracy: 0.8774 - loss: 0.3089 - val_accuracy: 0.9187 - val_loss: 0.2256
# Epoch 85/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - accuracy: 0.8595 - loss: 0.3321 - val_accuracy: 0.8923 - val_loss: 0.2744
# Epoch 86/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step - accuracy: 0.8772 - loss: 0.3062 - val_accuracy: 0.9019 - val_loss: 0.2569
# Epoch 87/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - accuracy: 0.8620 - loss: 0.3320 - val_accuracy: 0.9115 - val_loss: 0.2359
# Epoch 88/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - accuracy: 0.8526 - loss: 0.3320 - val_accuracy: 0.9163 - val_loss: 0.2390
# Epoch 89/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - accuracy: 0.8513 - loss: 0.3105 - val_accuracy: 0.9019 - val_loss: 0.2570
# Epoch 90/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - accuracy: 0.8776 - loss: 0.2999 - val_accuracy: 0.9306 - val_loss: 0.2181
# Epoch 91/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - accuracy: 0.8384 - loss: 0.3624 - val_accuracy: 0.9163 - val_loss: 0.2284
# Epoch 92/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - accuracy: 0.8018 - loss: 0.4091 - val_accuracy: 0.8421 - val_loss: 0.3500
# Epoch 93/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - accuracy: 0.8397 - loss: 0.3657 - val_accuracy: 0.9234 - val_loss: 0.2251
# Epoch 94/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - accuracy: 0.9049 - loss: 0.3013 - val_accuracy: 0.9258 - val_loss: 0.2119
# Epoch 95/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - accuracy: 0.8786 - loss: 0.3065 - val_accuracy: 0.8971 - val_loss: 0.2653
# Epoch 96/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - accuracy: 0.8591 - loss: 0.3262 - val_accuracy: 0.8756 - val_loss: 0.2972
# Epoch 97/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - accuracy: 0.8359 - loss: 0.3442 - val_accuracy: 0.8995 - val_loss: 0.2626
# Epoch 98/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step - accuracy: 0.8502 - loss: 0.3385 - val_accuracy: 0.9354 - val_loss: 0.2121
# Epoch 99/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 197ms/step - accuracy: 0.8895 - loss: 0.3113 - val_accuracy: 0.8971 - val_loss: 0.2641
# Epoch 100/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - accuracy: 0.8722 - loss: 0.3106 - val_accuracy: 0.9139 - val_loss: 0.2232
# Le modèle a été entraîné en 295.27 secondes.

# %%
end = time.time()
